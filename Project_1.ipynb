# %%
print('Lets play a quiz')

play = input('Do you want to play: ').lower()

if play == 'yes':
    print('Okayy! lets get started with the quiz :)')

else:
    quit()

score = 0

answer = input('What does cpu stands for: ').lower()
if answer == 'central processing unit':
    print('correct ! :)')
    score+=1
else:
    print('incorrect answer')

answer = input('What does GPU stands for? ').lower()
if answer == 'graphic processing unit':
    print('Correct ! :)')
    score+=1
else:
    print('incorrect')

print(f'Your score is {score}')
# Out:
# Do you want to play:  yes
# Okayy! lets get started with the quiz :)
# What does cpu stands for:  central processing unit
# correct ! :)
# What does GPU stands for?  graphic processing unit
# Correct ! :)
# Your score is 2
