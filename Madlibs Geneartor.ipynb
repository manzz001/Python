# %%
with open("Story.txt", "r") as f:
    story = f.read()


words = set()
start_of_word = -1

target_start = "<"
target_end = ">"

for i, char in enumerate(story):
    if char == target_start:
        start_of_word = i

    if char == target_end and start_of_word != -1:
        word = story[start_of_word: i + 1]
        words.add(word)
        start_of_word = -1


for word in words:
    answer = input("Enter a word for" + word + ": ")
    answers[word] = answer

for word in words:
    story = story.replace(word, answers[word])

print(story)


#print(words)  ## here I made a mistake by calling word instread calling words and wondering why am I getting only one word as a output.
# Out:
# Enter a word for<emotion>:  happy.
# Enter a word for<character>:  manjunath
# Enter a word for<adjective1>:  interesting
# Enter a word for<animal>:  dog
# Enter a word for<adverb>:  easily
# Enter a word for<weather_condition>:  sunny
# Enter a word for<place2>:  bangalore
# Enter a word for<terrain>:  city
# Enter a word for<emotion2>:  excited
# Enter a word for<object>:  car
# Enter a word for<place>:  house
# In the interesting land of house, a dog was feeling happy.. The dog had lost its car.
#
# Suddenly, a manjunath appeared. 'I will help you find your car,' they said.
#
# Together, they journeyed through city and faced the sunny. Finally, they found the car in a bangalore. The dog was so excited and thanked the manjunath. They lived easily ever after.
