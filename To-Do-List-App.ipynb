# %% [raw]
# 0. load  existing items
# 1. Create new task
# 2. list items
# 3. mark items as complete
# 4. Save items

# %%
 import json 


to_do_list = ['hello']

# %%
def load_task(file_name='to_do_list.json'):
    global to_do_list
    try:
        with open(file_name, 'r') as  file:
            to_do_list = json.load(file)
            print('Task loaded successfully.')

    except FileNotFopundError:
        print('no existing file found')

def create_task ():
    pass 

def mark_read():
    pass

def save_items():
    pass

def view_task():
    pass


def main():
    load_task()
    
    while True:
        print('To do list manager\n')
        print('1 : View tasks')
        print('2 : Add tasks')
        print('3 : Complete tasks')
        print('4 : Exit ')

        choice = input('Enter your value : ').strip()

        if choice == '1':
            view_task()
        elif choice == '2':
            create_task()
        elif choice == '3':
            mark_read()
        elif choice == '4':
            print('Goodbye')
            break
        else:
            print('Invalid choice try again') 


main()
# Out:
# Task loaded successfully.
# To do list manager
#
# 1 : View tasks
# 2 : Add tasks
# 3 : Complete tasks
# 4 : Exit
# Enter your value :  4
# Goodbye
