# %% [markdown]
# # GAME 1

# %%
import random

# %%
questions = {'What is the capityal of india' : 'delhi', 
             'What is the capityal of Karnataka' : 'bangalore',
             'Who is the PM of India' : 'narendra modi', 
             'Who is the CM of Karnataka' : 'siddaramayya',
             'What is the national animal of india' : 'tiger',
             'What is the national bird of India' : 'p  eacock'}

# %%
def python_trivia_game():
    questions_list = list(questions.keys())
    total_questions = 5
    score  = 0

    selected_questions = random.sample(questions_list, total_questions)

    for idx, question in enumerate(selected_questions):
        print(f"{idx + 1}. {question}")
        user_answer = input('Your answer is : ').lower().strip()
        correct_answer = questions[question]
        
        if user_answer == correct_answer.lower():
            print('correct!\n')
            score += 1

        else:
            print(f'Your answer is wrong. the correct answer is {correct_answer}.\n') 

    print(f'The game is over! your final score is : {score}/{total_questions}')
        
        
    
    

python_trivia_game()
# Out:
# 1. What is the national animal of india
# Your answer is :  tiger
# correct!
#
# 2. What is the national bird of India
# Your answer is :  peacock
# correct!
#
# 3. Who is the PM of India
# Your answer is :  nau
# Your answer is wrong. the correct answer is Narendrta Modi.
#
# 4. What is the capityal of india
# Your answer is :  delhi
# correct!
#
# 5. Who is the CM of Karnataka
# Your answer is :  ninu
# Your answer is wrong. the correct answer is Siddaramayya.
#
# The game is over! your final score is : 3/5
